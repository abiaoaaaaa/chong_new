# %% [markdown]
# # 测试训练好的模型的决策效果

# %%
import matplotlib.pyplot as plt
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3 import PPO,DDPG,DQN,A2C
from stable_baselines3.common.vec_env.dummy_vec_env import DummyVecEnv
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize, SubprocVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.callbacks import BaseCallback, EvalCallback
import gym
import numpy as np
import time
from stable_baselines3.common.callbacks import EvalCallback
import env
env = env.ElectricVehicleEnv()
#vec_env = make_vec_env(env, n_envs=4)
#check_env(env)

# %%
import numpy as np
from env import ElectricVehicleEnv
from stable_baselines3 import A2C
# 加载训练好的模型
#model = A2C.load("best_model/A2C/best_model.zip")
model = DQN.load("model/dqn_retrained_electric_vehicle.zip")
#model = A2C.load("model/a2c_electric_vehicle.zip")
#model = DQN.load("model/dqn_electric_vehicle.zip")
def print_state(state):
    """
    打印状态的每个属性，并标注其含义。
    """
    #print(f"  当前节点 (Current Node): {state[0]}")
    print(f"  当前电池电量 (Battery): {state[-1]}")
    print(f"  剩余时间 (Remaining Time): {state[-2]}")
    print("  其余节点的电量变化、距离变化和时间消耗信息已省略...")


def print_step_details(info):
    """
    打印每个步骤的详细信息。
    """
    print(f"  从节点 (From Node): {info['from_node']} 到节点 (To Node): {info['to_node']}")
    print(f"  距离缩短 (Distance_decrease): {info['distance_decrease']} km")
    print(f"  耗电 (Energy Consumed): {info['energy_consumed']} kWh")
    print(f"  是否充电 (Charging): {'Yes' if info['charging'] else 'No'}")
    if info['charging']:
        print(f"  充电量 (Energy Charged): {info['energy_charged']} kWh")
    print(f"  电量从 (Battery Start): {info['battery_start']} kWh 变成 (Battery End): {info['battery_end']} kWh")
    print(f"  剩余时间从 (Time Start): {info['time_start']} h 变成 (Time End): {info['time_end']} h")

# %% [markdown]
# # 测试模型

# %%
# 测试训练好的模型
obs, info = env.reset()
done = False

print("Initial State:")
print_state(obs)
step = 0
# 执行100步动作
for i in range(100):
    # 预测动作
    action, _states = model.predict(obs, deterministic=True)
    # 执行动作
    obs, reward, done,done1,  info = env.step(action)

    print("-" * 30)
    print(f"\nStep {step + 1}:")
    step+=1
    print_step_details(info)
    print_state(obs)
    print("Reward:", reward)
    print("Done:", done)
    
    if done:
        print("Episode finished! Resetting environment.")
        obs, info = env.reset(seed=14)
        print("Initial State:"+"-"*10)
        print_state(obs)
        step = 0
# Out:
# Initial State:
#   当前电池电量 (Battery): 30.0
#   剩余时间 (Remaining Time): 82.970703125
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 37 到节点 (To Node): 44
#   距离缩短 (Distance_decrease): 13.370419787 km
#   耗电 (Energy Consumed): 1.7329115244 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 43.76039203030303 kWh
#   电量从 (Battery Start): 30.0 kWh 变成 (Battery End): 72.02748050590303 kWh
#   剩余时间从 (Time Start): 1.659414125 h 变成 (Time End): 1.2218102046969697 h
#   当前电池电量 (Battery): 72.02748107910156
#   剩余时间 (Remaining Time): 61.090511322021484
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 220.91882607909474
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 44 到节点 (To Node): 26
#   距离缩短 (Distance_decrease): 1.5354000330000002 km
#   耗电 (Energy Consumed): 0.3824625048 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 5.591557087719298 kWh
#   电量从 (Battery Start): 72.02748050590303 kWh 变成 (Battery End): 77.23657508882232 kWh
#   剩余时间从 (Time Start): 1.2218102046969697 h 变成 (Time End): 1.1658946338197766 h
#   当前电池电量 (Battery): 77.236572265625
#   剩余时间 (Remaining Time): 58.29473114013672
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -62.69619278554021
# Done: False
# ------------------------------
#
# Step 3:
#   从节点 (From Node): 26 到节点 (To Node): 27
#   距离缩短 (Distance_decrease): 2.51029665 km
#   耗电 (Energy Consumed): 0.301235598 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 77.23657508882232 kWh 变成 (Battery End): 76.93533949082232 kWh
#   剩余时间从 (Time Start): 1.1658946338197766 h 变成 (Time End): 1.1240563563197767 h
#   当前电池电量 (Battery): 76.93534088134766
#   剩余时间 (Remaining Time): 56.202816009521484
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -23.064660509177685
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 33.0
#   剩余时间 (Remaining Time): 85.21442413330078
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 46 到节点 (To Node): 29
#   距离缩短 (Distance_decrease): 12.47907754 km
#   耗电 (Energy Consumed): 1.8718616310000002 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 33.0 kWh 变成 (Battery End): 31.128138369 kWh
#   剩余时间从 (Time Start): 1.704288521 h 变成 (Time End): 1.4547069702000002 h
#   当前电池电量 (Battery): 31.128137588500977
#   剩余时间 (Remaining Time): 72.7353515625
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -68.871861631
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 44.0
#   剩余时间 (Remaining Time): 89.81895446777344
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 36 到节点 (To Node): 35
#   距离缩短 (Distance_decrease): 3.363793636 km
#   耗电 (Energy Consumed): 0.43729317268 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 44.0 kWh 变成 (Battery End): 43.56270682732 kWh
#   剩余时间从 (Time Start): 1.796379152 h 变成 (Time End): 1.7162888273333334 h
#   当前电池电量 (Battery): 43.562705993652344
#   剩余时间 (Remaining Time): 85.81443786621094
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -56.43729317268
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 36.0
#   剩余时间 (Remaining Time): 74.61658477783203
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 33 到节点 (To Node): 46
#   距离缩短 (Distance_decrease): 1.2566400199999954 km
#   耗电 (Energy Consumed): 0.15084358416000002 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 36.0 kWh 变成 (Battery End): 35.84915641584 kWh
#   剩余时间从 (Time Start): 1.492331723 h 变成 (Time End): 1.469476634490909 h
#   当前电池电量 (Battery): 35.84915542602539
#   剩余时间 (Remaining Time): 73.47383117675781
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.00046781760001
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 46 到节点 (To Node): 27
#   距离缩短 (Distance_decrease): 5.510768280000001 km
#   耗电 (Energy Consumed): 0.8071533963599999 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 13.188780986274509 kWh
#   电量从 (Battery Start): 35.84915641584 kWh 变成 (Battery End): 48.23078400575451 kWh
#   剩余时间从 (Time Start): 1.469476634490909 h 变成 (Time End): 1.3375888246281638 h
#   当前电池电量 (Battery): 48.23078536987305
#   剩余时间 (Remaining Time): 66.87944030761719
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 16.75348375393017
# Done: False
# ------------------------------
#
# Step 3:
#   从节点 (From Node): 27 到节点 (To Node): 8
#   距离缩短 (Distance_decrease): 2.2517368300000022 km
#   耗电 (Energy Consumed): 0.82038329292 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 48.23078400575451 kWh 变成 (Battery End): 47.41040071283451 kWh
#   剩余时间从 (Time Start): 1.3375888246281638 h 变成 (Time End): 1.2197176618523016 h
#   当前电池电量 (Battery): 47.410400390625
#   剩余时间 (Remaining Time): 60.98588180541992
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -105.5017487332
# Done: False
# ------------------------------
#
# Step 4:
#   从节点 (From Node): 8 到节点 (To Node): 3
#   距离缩短 (Distance_decrease): 0.24946023999999767 km
#   耗电 (Energy Consumed): 0.03619365624 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 47.41040071283451 kWh 变成 (Battery End): 47.37420705659451 kWh
#   剩余时间从 (Time Start): 1.2197176618523016 h 变成 (Time End): 1.211339500685635 h
#   当前电池电量 (Battery): 47.37420654296875
#   剩余时间 (Remaining Time): 60.56697463989258
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.06258427440001
# Done: False
# ------------------------------
#
# Step 5:
#   从节点 (From Node): 3 到节点 (To Node): 8
#   距离缩短 (Distance_decrease): -0.24946023999999767 km
#   耗电 (Energy Consumed): 0.03619365624 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 47.37420705659451 kWh 变成 (Battery End): 47.338013400354505 kWh
#   剩余时间从 (Time Start): 1.211339500685635 h 变成 (Time End): 1.2029613395189682 h
#   当前电池电量 (Battery): 47.3380126953125
#   剩余时间 (Remaining Time): 60.148067474365234
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.6612888504
# Done: False
# ------------------------------
#
# Step 6:
#   从节点 (From Node): 8 到节点 (To Node): 3
#   距离缩短 (Distance_decrease): 0.24946023999999767 km
#   耗电 (Energy Consumed): 0.03619365624 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 47.338013400354505 kWh 变成 (Battery End): 47.3018197441145 kWh
#   剩余时间从 (Time Start): 1.2029613395189682 h 变成 (Time End): 1.1945831783523015 h
#   当前电池电量 (Battery): 47.30181884765625
#   剩余时间 (Remaining Time): 59.72916030883789
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.06258427440001
# Done: False
# ------------------------------
#
# Step 7:
#   从节点 (From Node): 3 到节点 (To Node): 8
#   距离缩短 (Distance_decrease): -0.24946023999999767 km
#   耗电 (Energy Consumed): 0.03619365624 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 47.3018197441145 kWh 变成 (Battery End): 47.2656260878745 kWh
#   剩余时间从 (Time Start): 1.1945831783523015 h 变成 (Time End): 1.1862050171856349 h
#   当前电池电量 (Battery): 47.265625
#   剩余时间 (Remaining Time): 59.31024932861328
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.6612888504
# Done: False
# ------------------------------
#
# Step 8:
#   从节点 (From Node): 8 到节点 (To Node): 3
#   距离缩短 (Distance_decrease): 0.24946023999999767 km
#   耗电 (Energy Consumed): 0.03619365624 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 47.2656260878745 kWh 变成 (Battery End): 47.2294324316345 kWh
#   剩余时间从 (Time Start): 1.1862050171856349 h 变成 (Time End): 1.1778268560189682 h
#   当前电池电量 (Battery): 47.22943115234375
#   剩余时间 (Remaining Time): 58.89134216308594
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.06258427440001
# Done: False
# ------------------------------
#
# Step 9:
#   从节点 (From Node): 3 到节点 (To Node): 8
#   距离缩短 (Distance_decrease): -0.24946023999999767 km
#   耗电 (Energy Consumed): 0.03619365624 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 47.2294324316345 kWh 变成 (Battery End): 47.1932387753945 kWh
#   剩余时间从 (Time Start): 1.1778268560189682 h 变成 (Time End): 1.1694486948523015 h
#   当前电池电量 (Battery): 47.1932373046875
#   剩余时间 (Remaining Time): 58.472434997558594
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.6612888504
# Done: False
# ------------------------------
#
# Step 10:
#   从节点 (From Node): 8 到节点 (To Node): 3
#   距离缩短 (Distance_decrease): 0.24946023999999767 km
#   耗电 (Energy Consumed): 0.03619365624 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 47.1932387753945 kWh 变成 (Battery End): 47.157045119154496 kWh
#   剩余时间从 (Time Start): 1.1694486948523015 h 变成 (Time End): 1.1610705336856348 h
#   当前电池电量 (Battery): 47.15704345703125
#   剩余时间 (Remaining Time): 58.05352783203125
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.06258427440001
# Done: False
# ------------------------------
#
# Step 11:
#   从节点 (From Node): 3 到节点 (To Node): 8
#   距离缩短 (Distance_decrease): -0.24946023999999767 km
#   耗电 (Energy Consumed): 0.03619365624 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 47.157045119154496 kWh 变成 (Battery End): 47.120851462914494 kWh
#   剩余时间从 (Time Start): 1.1610705336856348 h 变成 (Time End): 1.1526923725189682 h
#   当前电池电量 (Battery): 47.120849609375
#   剩余时间 (Remaining Time): 57.63461685180664
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -8100.6612888504
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 44.0
#   剩余时间 (Remaining Time): 89.02764892578125
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 26 到节点 (To Node): 29
#   距离缩短 (Distance_decrease): -3.273290145 km
#   耗电 (Energy Consumed): 0.6375102311999999 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 44.0 kWh 变成 (Battery End): 43.3624897688 kWh
#   剩余时间从 (Time Start): 1.780552972 h 变成 (Time End): 1.6972183012549018 h
#   当前电池电量 (Battery): 43.362491607666016
#   剩余时间 (Remaining Time): 84.86091613769531
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -111.2850375295
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 29 到节点 (To Node): 2
#   距离缩短 (Distance_decrease): 0.5393951339999994 km
#   耗电 (Energy Consumed): 0.99564642795 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 11.250242123728814 kWh
#   电量从 (Battery Start): 43.3624897688 kWh 变成 (Battery End): 53.61708546457882 kWh
#   剩余时间从 (Time Start): 1.6972183012549018 h 变成 (Time End): 1.5847158800176138 h
#   当前电池电量 (Battery): 53.61708450317383
#   剩余时间 (Remaining Time): 79.23579406738281
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -9.018717009518525
# Done: False
# ------------------------------
#
# Step 3:
#   从节点 (From Node): 2 到节点 (To Node): 27
#   距离缩短 (Distance_decrease): 5.244191661 km
#   耗电 (Energy Consumed): 0.78662874915 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 13.446645284615386 kWh
#   电量从 (Battery Start): 53.61708546457882 kWh 变成 (Battery End): 66.27710200004421 kWh
#   剩余时间从 (Time Start): 1.5847158800176138 h 变成 (Time End): 1.4502494271714599 h
#   当前电池电量 (Battery): 66.277099609375
#   剩余时间 (Remaining Time): 72.5124740600586
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 75.79919950600527
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 50.0
#   剩余时间 (Remaining Time): 92.92747497558594
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 7 到节点 (To Node): 45
#   距离缩短 (Distance_decrease): 2.2139197470000003 km
#   耗电 (Energy Consumed): 0.33333510504 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 7.4405157375 kWh
#   电量从 (Battery Start): 50.0 kWh 变成 (Battery End): 57.10718063246 kWh
#   剩余时间从 (Time Start): 1.858549488 h 变成 (Time End): 1.784144330625 h
#   当前电池电量 (Battery): 57.107181549072266
#   剩余时间 (Remaining Time): 89.20721435546875
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -28.807441586411016
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 45 到节点 (To Node): 2
#   距离缩短 (Distance_decrease): -0.7107812550000006 km
#   耗电 (Energy Consumed): 0.59330550888 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 57.10718063246 kWh 变成 (Battery End): 56.51387512358 kWh
#   剩余时间从 (Time Start): 1.784144330625 h 变成 (Time End): 1.6754803180096154 h
#   当前电池电量 (Battery): 56.51387405395508
#   剩余时间 (Remaining Time): 83.77401733398438
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -106.9281488458
# Done: False
# ------------------------------
#
# Step 3:
#   从节点 (From Node): 2 到节点 (To Node): 27
#   距离缩短 (Distance_decrease): 5.244191661 km
#   耗电 (Energy Consumed): 0.7341868325400001 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 13.446645284615386 kWh
#   电量从 (Battery Start): 56.51387512358 kWh 变成 (Battery End): 69.22633357565539 kWh
#   剩余时间从 (Time Start): 1.6754803180096154 h 变成 (Time End): 1.5410138651634615 h
#   当前电池电量 (Battery): 69.22633361816406
#   剩余时间 (Remaining Time): 77.05068969726562
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 80.71901621509227
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 42.0
#   剩余时间 (Remaining Time): 88.12479400634766
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 15 到节点 (To Node): 45
#   距离缩短 (Distance_decrease): 24.86069654 km
#   耗电 (Energy Consumed): 2.9832835848 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 42.0 kWh 变成 (Battery End): 39.0167164152 kWh
#   剩余时间从 (Time Start): 1.762495925 h 变成 (Time End): 1.0719210211111112 h
#   当前电池电量 (Battery): 39.01671600341797
#   剩余时间 (Remaining Time): 53.59605026245117
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -60.9832835848
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 42.0
#   剩余时间 (Remaining Time): 88.12479400634766
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 15 到节点 (To Node): 45
#   距离缩短 (Distance_decrease): 24.86069654 km
#   耗电 (Energy Consumed): 2.9832835848 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 42.0 kWh 变成 (Battery End): 39.0167164152 kWh
#   剩余时间从 (Time Start): 1.762495925 h 变成 (Time End): 1.0719210211111112 h
#   当前电池电量 (Battery): 39.01671600341797
#   剩余时间 (Remaining Time): 53.59605026245117
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -60.9832835848
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 33.0
#   剩余时间 (Remaining Time): 85.21442413330078
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 46 到节点 (To Node): 29
#   距离缩短 (Distance_decrease): 12.47907754 km
#   耗电 (Energy Consumed): 1.8718616310000002 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 33.0 kWh 变成 (Battery End): 31.128138369 kWh
#   剩余时间从 (Time Start): 1.704288521 h 变成 (Time End): 1.4547069702000002 h
#   当前电池电量 (Battery): 31.128137588500977
#   剩余时间 (Remaining Time): 72.7353515625
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -68.871861631
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 38.0
#   剩余时间 (Remaining Time): 80.168701171875
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 33 到节点 (To Node): 28
#   距离缩短 (Distance_decrease): 13.5454003 km
#   耗电 (Energy Consumed): 1.896356042 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 38.0 kWh 变成 (Battery End): 36.103643958 kWh
#   剩余时间从 (Time Start): 1.603373952 h 变成 (Time End): 1.3657353502456142 h
#   当前电池电量 (Battery): 36.10364532470703
#   剩余时间 (Remaining Time): 68.2867660522461
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -63.896356042
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 44.0
#   剩余时间 (Remaining Time): 89.81895446777344
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 36 到节点 (To Node): 35
#   距离缩短 (Distance_decrease): 3.363793636 km
#   耗电 (Energy Consumed): 0.43729317268 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 44.0 kWh 变成 (Battery End): 43.56270682732 kWh
#   剩余时间从 (Time Start): 1.796379152 h 变成 (Time End): 1.7162888273333334 h
#   当前电池电量 (Battery): 43.562705993652344
#   剩余时间 (Remaining Time): 85.81443786621094
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -56.43729317268
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 44.0
#   剩余时间 (Remaining Time): 89.02764892578125
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 26 到节点 (To Node): 29
#   距离缩短 (Distance_decrease): -3.273290145 km
#   耗电 (Energy Consumed): 0.6375102311999999 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 44.0 kWh 变成 (Battery End): 43.3624897688 kWh
#   剩余时间从 (Time Start): 1.780552972 h 变成 (Time End): 1.6972183012549018 h
#   当前电池电量 (Battery): 43.362491607666016
#   剩余时间 (Remaining Time): 84.86091613769531
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -111.2850375295
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 29 到节点 (To Node): 2
#   距离缩短 (Distance_decrease): 0.5393951339999994 km
#   耗电 (Energy Consumed): 0.99564642795 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 11.250242123728814 kWh
#   电量从 (Battery Start): 43.3624897688 kWh 变成 (Battery End): 53.61708546457882 kWh
#   剩余时间从 (Time Start): 1.6972183012549018 h 变成 (Time End): 1.5847158800176138 h
#   当前电池电量 (Battery): 53.61708450317383
#   剩余时间 (Remaining Time): 79.23579406738281
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -9.018717009518525
# Done: False
# ------------------------------
#
# Step 3:
#   从节点 (From Node): 2 到节点 (To Node): 27
#   距离缩短 (Distance_decrease): 5.244191661 km
#   耗电 (Energy Consumed): 0.78662874915 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 13.446645284615386 kWh
#   电量从 (Battery Start): 53.61708546457882 kWh 变成 (Battery End): 66.27710200004421 kWh
#   剩余时间从 (Time Start): 1.5847158800176138 h 变成 (Time End): 1.4502494271714599 h
#   当前电池电量 (Battery): 66.277099609375
#   剩余时间 (Remaining Time): 72.5124740600586
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 75.79919950600527
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 33.0
#   剩余时间 (Remaining Time): 85.21442413330078
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 46 到节点 (To Node): 29
#   距离缩短 (Distance_decrease): 12.47907754 km
#   耗电 (Energy Consumed): 1.8718616310000002 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 33.0 kWh 变成 (Battery End): 31.128138369 kWh
#   剩余时间从 (Time Start): 1.704288521 h 变成 (Time End): 1.4547069702000002 h
#   当前电池电量 (Battery): 31.128137588500977
#   剩余时间 (Remaining Time): 72.7353515625
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -68.871861631
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 40.0
#   剩余时间 (Remaining Time): 73.30824279785156
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 47 到节点 (To Node): 10
#   距离缩短 (Distance_decrease): 27.0972936 km
#   耗电 (Energy Consumed): 3.522648168 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 40.0 kWh 变成 (Battery End): 36.477351832 kWh
#   剩余时间从 (Time Start): 1.466164882 h 变成 (Time End): 0.92421901 h
#   当前电池电量 (Battery): 36.477352142333984
#   剩余时间 (Remaining Time): 46.2109489440918
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -63.522648168
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 48.0
#   剩余时间 (Remaining Time): 87.76982879638672
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 28 到节点 (To Node): 16
#   距离缩短 (Distance_decrease): 15.62743528 km
#   耗电 (Energy Consumed): 1.7190178808 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 48.0 kWh 变成 (Battery End): 46.2809821192 kWh
#   剩余时间从 (Time Start): 1.755396641 h 变成 (Time End): 1.2670392885 h
#   当前电池电量 (Battery): 46.280982971191406
#   剩余时间 (Remaining Time): 63.35196304321289
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -53.7190178808
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 37.0
#   剩余时间 (Remaining Time): 86.81204223632812
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 27 到节点 (To Node): 25
#   距离缩短 (Distance_decrease): 8.112239469 km
#   耗电 (Energy Consumed): 0.97346873628 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 20.2805986725 kWh
#   电量从 (Battery Start): 37.0 kWh 变成 (Battery End): 56.30712993622 kWh
#   剩余时间从 (Time Start): 1.736240849 h 变成 (Time End): 1.533434862275 h
#   当前电池电量 (Battery): 56.30712890625
#   剩余时间 (Remaining Time): 76.67174530029297
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 135.4238524239512
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 50.0
#   剩余时间 (Remaining Time): 92.92747497558594
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 7 到节点 (To Node): 45
#   距离缩短 (Distance_decrease): 2.2139197470000003 km
#   耗电 (Energy Consumed): 0.33333510504 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 7.4405157375 kWh
#   电量从 (Battery Start): 50.0 kWh 变成 (Battery End): 57.10718063246 kWh
#   剩余时间从 (Time Start): 1.858549488 h 变成 (Time End): 1.784144330625 h
#   当前电池电量 (Battery): 57.107181549072266
#   剩余时间 (Remaining Time): 89.20721435546875
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -28.807441586411016
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 45 到节点 (To Node): 2
#   距离缩短 (Distance_decrease): -0.7107812550000006 km
#   耗电 (Energy Consumed): 0.59330550888 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 57.10718063246 kWh 变成 (Battery End): 56.51387512358 kWh
#   剩余时间从 (Time Start): 1.784144330625 h 变成 (Time End): 1.6754803180096154 h
#   当前电池电量 (Battery): 56.51387405395508
#   剩余时间 (Remaining Time): 83.77401733398438
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -106.9281488458
# Done: False
# ------------------------------
#
# Step 3:
#   从节点 (From Node): 2 到节点 (To Node): 27
#   距离缩短 (Distance_decrease): 5.244191661 km
#   耗电 (Energy Consumed): 0.7341868325400001 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 13.446645284615386 kWh
#   电量从 (Battery Start): 56.51387512358 kWh 变成 (Battery End): 69.22633357565539 kWh
#   剩余时间从 (Time Start): 1.6754803180096154 h 变成 (Time End): 1.5410138651634615 h
#   当前电池电量 (Battery): 69.22633361816406
#   剩余时间 (Remaining Time): 77.05068969726562
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 80.71901621509227
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 48.0
#   剩余时间 (Remaining Time): 81.12332916259766
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 31 到节点 (To Node): 45
#   距离缩短 (Distance_decrease): 21.16162874 km
#   耗电 (Energy Consumed): 2.7510117362 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 48.0 kWh 变成 (Battery End): 45.2489882638 kWh
#   剩余时间从 (Time Start): 1.622466536 h 变成 (Time End): 1.172219116 h
#   当前电池电量 (Battery): 45.24898910522461
#   剩余时间 (Remaining Time): 58.61095428466797
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -54.7510117362
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 42.0
#   剩余时间 (Remaining Time): 80.1118392944336
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 48 到节点 (To Node): 26
#   距离缩短 (Distance_decrease): 3.847296528 km
#   耗电 (Energy Consumed): 0.50014854864 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 11.315578023529413 kWh
#   电量从 (Battery Start): 42.0 kWh 变成 (Battery End): 52.81542947488941 kWh
#   剩余时间从 (Time Start): 1.60223672 h 变成 (Time End): 1.489080939764706 h
#   当前电池电量 (Battery): 52.8154296875
#   剩余时间 (Remaining Time): 74.45404815673828
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 57.97973726367877
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 34.0
#   剩余时间 (Remaining Time): 89.90509796142578
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 39 到节点 (To Node): 20
#   距离缩短 (Distance_decrease): 2.1415481219999997 km
#   耗电 (Energy Consumed): 1.3061225720200003 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 24.551176165789474 kWh
#   电量从 (Battery Start): 34.0 kWh 变成 (Battery End): 57.24505359376947 kWh
#   剩余时间从 (Time Start): 1.798101974 h 变成 (Time End): 1.5525902123421051 h
#   当前电池电量 (Battery): 57.245052337646484
#   剩余时间 (Remaining Time): 77.62950897216797
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 101.92667508988663
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 20 到节点 (To Node): 32
#   距离缩短 (Distance_decrease): 4.09314919 km
#   耗电 (Energy Consumed): 0.5730408866000001 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 10.495254333333333 kWh
#   电量从 (Battery Start): 57.24505359376947 kWh 变成 (Battery End): 67.16726704050281 kWh
#   剩余时间从 (Time Start): 1.5525902123421051 h 变成 (Time End): 1.4476376690087718 h
#   当前电池电量 (Battery): 67.16726684570312
#   剩余时间 (Remaining Time): 72.38188171386719
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 51.66372907909505
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 48.0
#   剩余时间 (Remaining Time): 82.92649841308594
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 43 到节点 (To Node): 41
#   距离缩短 (Distance_decrease): 11.74103757 km
#   耗电 (Energy Consumed): 1.4089245083999997 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 48.0 kWh 变成 (Battery End): 46.5910754916 kWh
#   剩余时间从 (Time Start): 1.658529921 h 变成 (Time End): 1.2797867735806452 h
#   当前电池电量 (Battery): 46.5910758972168
#   剩余时间 (Remaining Time): 63.98933792114258
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -53.4089245084
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 39.0
#   剩余时间 (Remaining Time): 86.71542358398438
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 17 到节点 (To Node): 3
#   距离缩短 (Distance_decrease): 23.59326126 km
#   耗电 (Energy Consumed): 2.8311913512 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 39.0 kWh 变成 (Battery End): 36.1688086488 kWh
#   剩余时间从 (Time Start): 1.734308483 h 变成 (Time End): 1.2973962374444445 h
#   当前电池电量 (Battery): 36.16880798339844
#   剩余时间 (Remaining Time): 64.86981201171875
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -63.8311913512
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 40.0
#   剩余时间 (Remaining Time): 89.14132690429688
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 19 到节点 (To Node): 27
#   距离缩短 (Distance_decrease): 16.762030927 km
#   耗电 (Energy Consumed): 2.8675980432 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 40.0 kWh 变成 (Battery End): 37.1324019568 kWh
#   剩余时间从 (Time Start): 1.782826488 h 变成 (Time End): 1.2951397459591836 h
#   当前电池电量 (Battery): 37.13240051269531
#   剩余时间 (Remaining Time): 64.75698852539062
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -108.5615433196
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 27 到节点 (To Node): 26
#   距离缩短 (Distance_decrease): 0.858509143 km
#   耗电 (Energy Consumed): 0.301235598 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 37.1324019568 kWh 变成 (Battery End): 36.831166358800004 kWh
#   剩余时间从 (Time Start): 1.2951397459591836 h 变成 (Time End): 1.2533014684591837 h
#   当前电池电量 (Battery): 36.8311653137207
#   剩余时间 (Remaining Time): 62.66507339477539
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -101.9821450084
# Done: False
# ------------------------------
#
# Step 3:
#   从节点 (From Node): 26 到节点 (To Node): 44
#   距离缩短 (Distance_decrease): 3.18718754 km
#   耗电 (Energy Consumed): 0.3824625048 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 5.591557087719298 kWh
#   电量从 (Battery Start): 36.831166358800004 kWh 变成 (Battery End): 42.040260941719296 kWh
#   剩余时间从 (Time Start): 1.2533014684591837 h 变成 (Time End): 1.1973858975819907 h
#   当前电池电量 (Battery): 42.040260314941406
#   剩余时间 (Remaining Time): 59.869293212890625
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -20.40559877920878
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 41.0
#   剩余时间 (Remaining Time): 84.91912078857422
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 8 到节点 (To Node): 48
#   距离缩短 (Distance_decrease): 5.92766217 km
#   耗电 (Energy Consumed): 1.07708231917 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 41.0 kWh 变成 (Battery End): 39.92291768083 kWh
#   剩余时间从 (Time Start): 1.698382348 h 变成 (Time End): 1.5221004627021277 h
#   当前电池电量 (Battery): 39.922916412353516
#   剩余时间 (Remaining Time): 76.10502624511719
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -103.0648623707
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 48 到节点 (To Node): 40
#   距离缩短 (Distance_decrease): 13.00440104 km
#   耗电 (Energy Consumed): 1.6905721352 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 29.55545690909091 kWh
#   电量从 (Battery Start): 39.92291768083 kWh 变成 (Battery End): 67.7878024547209 kWh
#   剩余时间从 (Time Start): 1.5221004627021277 h 变成 (Time End): 1.2265458936112186 h
#   当前电池电量 (Battery): 67.78780364990234
#   剩余时间 (Remaining Time): 61.327293395996094
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 181.2328158719751
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 39.0
#   剩余时间 (Remaining Time): 82.9510498046875
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 30 到节点 (To Node): 3
#   距离缩短 (Distance_decrease): 16.86738286 km
#   耗电 (Energy Consumed): 2.1927597718 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 39.0 kWh 变成 (Battery End): 36.8072402282 kWh
#   剩余时间从 (Time Start): 1.659021022 h 变成 (Time End): 1.2151425256842106 h
#   当前电池电量 (Battery): 36.8072395324707
#   剩余时间 (Remaining Time): 60.75712585449219
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -63.1927597718
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 40.0
#   剩余时间 (Remaining Time): 73.30824279785156
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 47 到节点 (To Node): 10
#   距离缩短 (Distance_decrease): 27.0972936 km
#   耗电 (Energy Consumed): 3.522648168 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 40.0 kWh 变成 (Battery End): 36.477351832 kWh
#   剩余时间从 (Time Start): 1.466164882 h 变成 (Time End): 0.92421901 h
#   当前电池电量 (Battery): 36.477352142333984
#   剩余时间 (Remaining Time): 46.2109489440918
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -63.522648168
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 44.0
#   剩余时间 (Remaining Time): 89.81895446777344
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 36 到节点 (To Node): 35
#   距离缩短 (Distance_decrease): 3.363793636 km
#   耗电 (Energy Consumed): 0.43729317268 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 44.0 kWh 变成 (Battery End): 43.56270682732 kWh
#   剩余时间从 (Time Start): 1.796379152 h 变成 (Time End): 1.7162888273333334 h
#   当前电池电量 (Battery): 43.562705993652344
#   剩余时间 (Remaining Time): 85.81443786621094
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -56.43729317268
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 36.0
#   剩余时间 (Remaining Time): 81.0972671508789
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 40 到节点 (To Node): 20
#   距离缩短 (Distance_decrease): 10.75610203 km
#   耗电 (Energy Consumed): 1.6134153045 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 25.609766738095235 kWh
#   电量从 (Battery Start): 36.0 kWh 变成 (Battery End): 59.99635143359524 kWh
#   剩余时间从 (Time Start): 1.621945296 h 变成 (Time End): 1.3658476286190477 h
#   当前电池电量 (Battery): 59.99635314941406
#   剩余时间 (Remaining Time): 68.2923812866211
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 175.6573805384532
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 46.0
#   剩余时间 (Remaining Time): 84.40275573730469
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 12 到节点 (To Node): 15
#   距离缩短 (Distance_decrease): -0.38911006000000015 km
#   耗电 (Energy Consumed): 0.14810242272 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 46.0 kWh 变成 (Battery End): 45.85189757728 kWh
#   剩余时间从 (Time Start): 1.688055073 h 变成 (Time End): 1.651755459588235 h
#   当前电池电量 (Battery): 45.851898193359375
#   剩余时间 (Remaining Time): 82.58777618408203
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -101.9479562992
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 15 到节点 (To Node): 3
#   距离缩短 (Distance_decrease): 23.469514818 km
#   耗电 (Energy Consumed): 2.8232764080000003 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 45.85189757728 kWh 变成 (Battery End): 43.02862116928 kWh
#   剩余时间从 (Time Start): 1.651755459588235 h 变成 (Time End): 1.2239863068609624 h
#   当前电池电量 (Battery): 43.028621673583984
#   剩余时间 (Remaining Time): 61.19931411743164
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.0693462984
# Done: False
# ------------------------------
#
# Step 3:
#   从节点 (From Node): 3 到节点 (To Node): 7
#   距离缩短 (Distance_decrease): -0.010580739999999977 km
#   耗电 (Energy Consumed): 0.00238810344 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 43.02862116928 kWh 变成 (Battery End): 43.02623306584 kWh
#   剩余时间从 (Time Start): 1.2239863068609624 h 变成 (Time End): 1.2235234961167765 h
#   当前电池电量 (Battery): 43.0262336730957
#   剩余时间 (Remaining Time): 61.17617416381836
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.0365779224
# Done: False
# ------------------------------
#
# Step 4:
#   从节点 (From Node): 7 到节点 (To Node): 3
#   距离缩短 (Distance_decrease): 0.010580739999999977 km
#   耗电 (Energy Consumed): 0.00238810344 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 43.02623306584 kWh 变成 (Battery End): 43.023844962400005 kWh
#   剩余时间从 (Time Start): 1.2235234961167765 h 变成 (Time End): 1.2230606853725905 h
#   当前电池电量 (Battery): 43.02384567260742
#   剩余时间 (Remaining Time): 61.15303421020508
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.0111841464
# Done: False
# ------------------------------
#
# Step 5:
#   从节点 (From Node): 3 到节点 (To Node): 7
#   距离缩短 (Distance_decrease): -0.010580739999999977 km
#   耗电 (Energy Consumed): 0.00238810344 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 43.023844962400005 kWh 变成 (Battery End): 43.02145685896001 kWh
#   剩余时间从 (Time Start): 1.2230606853725905 h 变成 (Time End): 1.2225978746284045 h
#   当前电池电量 (Battery): 43.02145767211914
#   剩余时间 (Remaining Time): 61.1298942565918
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.0365779224
# Done: False
# ------------------------------
#
# Step 6:
#   从节点 (From Node): 7 到节点 (To Node): 3
#   距离缩短 (Distance_decrease): 0.010580739999999977 km
#   耗电 (Energy Consumed): 0.00238810344 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 43.02145685896001 kWh 变成 (Battery End): 43.01906875552001 kWh
#   剩余时间从 (Time Start): 1.2225978746284045 h 变成 (Time End): 1.2221350638842186 h
#   当前电池电量 (Battery): 43.01906967163086
#   剩余时间 (Remaining Time): 61.106754302978516
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.0111841464
# Done: False
# ------------------------------
#
# Step 7:
#   从节点 (From Node): 3 到节点 (To Node): 7
#   距离缩短 (Distance_decrease): -0.010580739999999977 km
#   耗电 (Energy Consumed): 0.00238810344 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 43.01906875552001 kWh 变成 (Battery End): 43.01668065208001 kWh
#   剩余时间从 (Time Start): 1.2221350638842186 h 变成 (Time End): 1.2216722531400326 h
#   当前电池电量 (Battery): 43.01668167114258
#   剩余时间 (Remaining Time): 61.083614349365234
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.0365779224
# Done: False
# ------------------------------
#
# Step 8:
#   从节点 (From Node): 7 到节点 (To Node): 3
#   距离缩短 (Distance_decrease): 0.010580739999999977 km
#   耗电 (Energy Consumed): 0.00238810344 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 43.01668065208001 kWh 变成 (Battery End): 43.014292548640015 kWh
#   剩余时间从 (Time Start): 1.2216722531400326 h 变成 (Time End): 1.2212094423958466 h
#   当前电池电量 (Battery): 43.0142936706543
#   剩余时间 (Remaining Time): 61.06047058105469
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.0111841464
# Done: False
# ------------------------------
#
# Step 9:
#   从节点 (From Node): 3 到节点 (To Node): 7
#   距离缩短 (Distance_decrease): -0.010580739999999977 km
#   耗电 (Energy Consumed): 0.00238810344 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 43.014292548640015 kWh 变成 (Battery End): 43.01190444520002 kWh
#   剩余时间从 (Time Start): 1.2212094423958466 h 变成 (Time End): 1.2207466316516606 h
#   当前电池电量 (Battery): 43.011905670166016
#   剩余时间 (Remaining Time): 61.037330627441406
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.0365779224
# Done: False
# ------------------------------
#
# Step 10:
#   从节点 (From Node): 7 到节点 (To Node): 3
#   距离缩短 (Distance_decrease): 0.010580739999999977 km
#   耗电 (Energy Consumed): 0.00238810344 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 43.01190444520002 kWh 变成 (Battery End): 43.00951634176002 kWh
#   剩余时间从 (Time Start): 1.2207466316516606 h 变成 (Time End): 1.2202838209074747 h
#   当前电池电量 (Battery): 43.009517669677734
#   剩余时间 (Remaining Time): 61.014190673828125
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.0111841464
# Done: False
# ------------------------------
#
# Step 11:
#   从节点 (From Node): 3 到节点 (To Node): 7
#   距离缩短 (Distance_decrease): -0.010580739999999977 km
#   耗电 (Energy Consumed): 0.00238810344 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 43.00951634176002 kWh 变成 (Battery End): 43.00712823832002 kWh
#   剩余时间从 (Time Start): 1.2202838209074747 h 变成 (Time End): 1.2198210101632887 h
#   当前电池电量 (Battery): 43.00712966918945
#   剩余时间 (Remaining Time): 60.991050720214844
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -8100.0365779224
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 33.0
#   剩余时间 (Remaining Time): 81.90269470214844
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 1 到节点 (To Node): 48
#   距离缩短 (Distance_decrease): 5.1299607599999995 km
#   耗电 (Energy Consumed): 0.7237123189800001 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 33.0 kWh 变成 (Battery End): 32.27628768102 kWh
#   剩余时间从 (Time Start): 1.638053865 h 变成 (Time End): 1.5504373614915254 h
#   当前电池电量 (Battery): 32.27628707885742
#   剩余时间 (Remaining Time): 77.52186584472656
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.0551781258
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 48 到节点 (To Node): 10
#   距离缩短 (Distance_decrease): 16.099290504 km
#   耗电 (Energy Consumed): 2.7337355248 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 32.27628768102 kWh 变成 (Battery End): 29.54255215622 kWh
#   剩余时间从 (Time Start): 1.5504373614915254 h 变成 (Time End): 1.0622703034915255 h
#   当前电池电量 (Battery): 29.542552947998047
#   剩余时间 (Remaining Time): 53.1135139465332
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -104.7983485424
# Done: False
# ------------------------------
#
# Step 3:
#   从节点 (From Node): 10 到节点 (To Node): 19
#   距离缩短 (Distance_decrease): 1.781318916 km
#   耗电 (Energy Consumed): 0.24938464824 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 3.2387616654545455 kWh
#   电量从 (Battery Start): 29.54255215622 kWh 变成 (Battery End): 32.53192917343455 kWh
#   剩余时间从 (Time Start): 1.0622703034915255 h 变成 (Time End): 1.0298826868369801 h
#   当前电池电量 (Battery): 32.53192901611328
#   剩余时间 (Remaining Time): 51.49413299560547
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -47.1052205118541
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 48.0
#   剩余时间 (Remaining Time): 87.76982879638672
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 28 到节点 (To Node): 16
#   距离缩短 (Distance_decrease): 15.62743528 km
#   耗电 (Energy Consumed): 1.7190178808 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 48.0 kWh 变成 (Battery End): 46.2809821192 kWh
#   剩余时间从 (Time Start): 1.755396641 h 变成 (Time End): 1.2670392885 h
#   当前电池电量 (Battery): 46.280982971191406
#   剩余时间 (Remaining Time): 63.35196304321289
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -53.7190178808
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 48.0
#   剩余时间 (Remaining Time): 81.12332916259766
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 31 到节点 (To Node): 45
#   距离缩短 (Distance_decrease): 21.16162874 km
#   耗电 (Energy Consumed): 2.7510117362 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 48.0 kWh 变成 (Battery End): 45.2489882638 kWh
#   剩余时间从 (Time Start): 1.622466536 h 变成 (Time End): 1.172219116 h
#   当前电池电量 (Battery): 45.24898910522461
#   剩余时间 (Remaining Time): 58.61095428466797
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -54.7510117362
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 48.0
#   剩余时间 (Remaining Time): 81.12332916259766
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 31 到节点 (To Node): 45
#   距离缩短 (Distance_decrease): 21.16162874 km
#   耗电 (Energy Consumed): 2.7510117362 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 48.0 kWh 变成 (Battery End): 45.2489882638 kWh
#   剩余时间从 (Time Start): 1.622466536 h 变成 (Time End): 1.172219116 h
#   当前电池电量 (Battery): 45.24898910522461
#   剩余时间 (Remaining Time): 58.61095428466797
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -54.7510117362
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 48.0
#   剩余时间 (Remaining Time): 82.92649841308594
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 43 到节点 (To Node): 41
#   距离缩短 (Distance_decrease): 11.74103757 km
#   耗电 (Energy Consumed): 1.4089245083999997 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 48.0 kWh 变成 (Battery End): 46.5910754916 kWh
#   剩余时间从 (Time Start): 1.658529921 h 变成 (Time End): 1.2797867735806452 h
#   当前电池电量 (Battery): 46.5910758972168
#   剩余时间 (Remaining Time): 63.98933792114258
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -53.4089245084
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 40.0
#   剩余时间 (Remaining Time): 79.24793243408203
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 22 到节点 (To Node): 20
#   距离缩短 (Distance_decrease): 26.74451858 km
#   耗电 (Energy Consumed): 2.9418970438 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 40.0 kWh 变成 (Battery End): 37.0581029562 kWh
#   剩余时间从 (Time Start): 1.584958705 h 变成 (Time End): 0.962993156627907 h
#   当前电池电量 (Battery): 37.058101654052734
#   剩余时间 (Remaining Time): 48.149658203125
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -62.9418970438
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 50.0
#   剩余时间 (Remaining Time): 92.92747497558594
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 7 到节点 (To Node): 45
#   距离缩短 (Distance_decrease): 2.2139197470000003 km
#   耗电 (Energy Consumed): 0.33333510504 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 7.4405157375 kWh
#   电量从 (Battery Start): 50.0 kWh 变成 (Battery End): 57.10718063246 kWh
#   剩余时间从 (Time Start): 1.858549488 h 变成 (Time End): 1.784144330625 h
#   当前电池电量 (Battery): 57.107181549072266
#   剩余时间 (Remaining Time): 89.20721435546875
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -28.807441586411016
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 45 到节点 (To Node): 2
#   距离缩短 (Distance_decrease): -0.7107812550000006 km
#   耗电 (Energy Consumed): 0.59330550888 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 57.10718063246 kWh 变成 (Battery End): 56.51387512358 kWh
#   剩余时间从 (Time Start): 1.784144330625 h 变成 (Time End): 1.6754803180096154 h
#   当前电池电量 (Battery): 56.51387405395508
#   剩余时间 (Remaining Time): 83.77401733398438
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -106.9281488458
# Done: False
# ------------------------------
#
# Step 3:
#   从节点 (From Node): 2 到节点 (To Node): 27
#   距离缩短 (Distance_decrease): 5.244191661 km
#   耗电 (Energy Consumed): 0.7341868325400001 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 13.446645284615386 kWh
#   电量从 (Battery Start): 56.51387512358 kWh 变成 (Battery End): 69.22633357565539 kWh
#   剩余时间从 (Time Start): 1.6754803180096154 h 变成 (Time End): 1.5410138651634615 h
#   当前电池电量 (Battery): 69.22633361816406
#   剩余时间 (Remaining Time): 77.05068969726562
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 80.71901621509227
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 44.0
#   剩余时间 (Remaining Time): 89.81895446777344
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 36 到节点 (To Node): 35
#   距离缩短 (Distance_decrease): 3.363793636 km
#   耗电 (Energy Consumed): 0.43729317268 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 44.0 kWh 变成 (Battery End): 43.56270682732 kWh
#   剩余时间从 (Time Start): 1.796379152 h 变成 (Time End): 1.7162888273333334 h
#   当前电池电量 (Battery): 43.562705993652344
#   剩余时间 (Remaining Time): 85.81443786621094
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -56.43729317268
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 43.0
#   剩余时间 (Remaining Time): 90.54013061523438
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 28 到节点 (To Node): 13
#   距离缩短 (Distance_decrease): 24.60471319 km
#   耗电 (Energy Consumed): 3.4446598466 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 43.0 kWh 变成 (Battery End): 39.5553401534 kWh
#   剩余时间从 (Time Start): 1.81080266 h 变成 (Time End): 1.3791410250877194 h
#   当前电池电量 (Battery): 39.55533981323242
#   剩余时间 (Remaining Time): 68.9570541381836
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -60.4446598466
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 33.0
#   剩余时间 (Remaining Time): 76.00495910644531
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 24 到节点 (To Node): 25
#   距离缩短 (Distance_decrease): 14.02364708 km
#   耗电 (Energy Consumed): 1.4023647080000001 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 33.0 kWh 变成 (Battery End): 31.597635292 kWh
#   剩余时间从 (Time Start): 1.520099127 h 变成 (Time End): 1.1695079499999999 h
#   当前电池电量 (Battery): 31.59763526916504
#   剩余时间 (Remaining Time): 58.475399017333984
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -68.402364708
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 39.0
#   剩余时间 (Remaining Time): 84.48882293701172
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 3 到节点 (To Node): 31
#   距离缩短 (Distance_decrease): 19.6088641 km
#   耗电 (Energy Consumed): 1.9608864100000003 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 39.0 kWh 变成 (Battery End): 37.03911359 kWh
#   剩余时间从 (Time Start): 1.689776436 h 变成 (Time End): 1.3197978680754718 h
#   当前电池电量 (Battery): 37.03911209106445
#   剩余时间 (Remaining Time): 65.9898910522461
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -62.96088641
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 43.0
#   剩余时间 (Remaining Time): 91.16085052490234
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 41 到节点 (To Node): 31
#   距离缩短 (Distance_decrease): 18.965248011 km
#   耗电 (Energy Consumed): 2.4817970309 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 43.0 kWh 变成 (Battery End): 40.5182029691 kWh
#   剩余时间从 (Time Start): 1.823217049 h 变成 (Time End): 1.1965006270555554 h
#   当前电池电量 (Battery): 40.51820373535156
#   剩余时间 (Remaining Time): 59.82503128051758
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -103.9561974969
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 31 到节点 (To Node): 32
#   距离缩短 (Distance_decrease): 2.268320579 km
#   耗电 (Energy Consumed): 0.24951526369 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 40.5182029691 kWh 变成 (Battery End): 40.26868770541 kWh
#   剩余时间从 (Time Start): 1.1965006270555554 h 变成 (Time End): 1.1502083703412698 h
#   当前电池电量 (Battery): 40.2686882019043
#   剩余时间 (Remaining Time): 57.51041793823242
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -59.73131229459
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 33.0
#   剩余时间 (Remaining Time): 81.90269470214844
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 1 到节点 (To Node): 48
#   距离缩短 (Distance_decrease): 5.1299607599999995 km
#   耗电 (Energy Consumed): 0.7237123189800001 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 33.0 kWh 变成 (Battery End): 32.27628768102 kWh
#   剩余时间从 (Time Start): 1.638053865 h 变成 (Time End): 1.5504373614915254 h
#   当前电池电量 (Battery): 32.27628707885742
#   剩余时间 (Remaining Time): 77.52186584472656
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.0551781258
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 48 到节点 (To Node): 10
#   距离缩短 (Distance_decrease): 16.099290504 km
#   耗电 (Energy Consumed): 2.7337355248 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 32.27628768102 kWh 变成 (Battery End): 29.54255215622 kWh
#   剩余时间从 (Time Start): 1.5504373614915254 h 变成 (Time End): 1.0622703034915255 h
#   当前电池电量 (Battery): 29.542552947998047
#   剩余时间 (Remaining Time): 53.1135139465332
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -104.7983485424
# Done: False
# ------------------------------
#
# Step 3:
#   从节点 (From Node): 10 到节点 (To Node): 19
#   距离缩短 (Distance_decrease): 1.781318916 km
#   耗电 (Energy Consumed): 0.24938464824 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 3.2387616654545455 kWh
#   电量从 (Battery Start): 29.54255215622 kWh 变成 (Battery End): 32.53192917343455 kWh
#   剩余时间从 (Time Start): 1.0622703034915255 h 变成 (Time End): 1.0298826868369801 h
#   当前电池电量 (Battery): 32.53192901611328
#   剩余时间 (Remaining Time): 51.49413299560547
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -47.1052205118541
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 41.0
#   剩余时间 (Remaining Time): 84.91912078857422
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 8 到节点 (To Node): 48
#   距离缩短 (Distance_decrease): 5.92766217 km
#   耗电 (Energy Consumed): 1.07708231917 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 41.0 kWh 变成 (Battery End): 39.92291768083 kWh
#   剩余时间从 (Time Start): 1.698382348 h 变成 (Time End): 1.5221004627021277 h
#   当前电池电量 (Battery): 39.922916412353516
#   剩余时间 (Remaining Time): 76.10502624511719
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -103.0648623707
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 48 到节点 (To Node): 40
#   距离缩短 (Distance_decrease): 13.00440104 km
#   耗电 (Energy Consumed): 1.6905721352 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 29.55545690909091 kWh
#   电量从 (Battery Start): 39.92291768083 kWh 变成 (Battery End): 67.7878024547209 kWh
#   剩余时间从 (Time Start): 1.5221004627021277 h 变成 (Time End): 1.2265458936112186 h
#   当前电池电量 (Battery): 67.78780364990234
#   剩余时间 (Remaining Time): 61.327293395996094
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 181.2328158719751
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 50.0
#   剩余时间 (Remaining Time): 92.92747497558594
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 7 到节点 (To Node): 45
#   距离缩短 (Distance_decrease): 2.2139197470000003 km
#   耗电 (Energy Consumed): 0.33333510504 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 7.4405157375 kWh
#   电量从 (Battery Start): 50.0 kWh 变成 (Battery End): 57.10718063246 kWh
#   剩余时间从 (Time Start): 1.858549488 h 变成 (Time End): 1.784144330625 h
#   当前电池电量 (Battery): 57.107181549072266
#   剩余时间 (Remaining Time): 89.20721435546875
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -28.807441586411016
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 45 到节点 (To Node): 2
#   距离缩短 (Distance_decrease): -0.7107812550000006 km
#   耗电 (Energy Consumed): 0.59330550888 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 57.10718063246 kWh 变成 (Battery End): 56.51387512358 kWh
#   剩余时间从 (Time Start): 1.784144330625 h 变成 (Time End): 1.6754803180096154 h
#   当前电池电量 (Battery): 56.51387405395508
#   剩余时间 (Remaining Time): 83.77401733398438
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -106.9281488458
# Done: False
# ------------------------------
#
# Step 3:
#   从节点 (From Node): 2 到节点 (To Node): 27
#   距离缩短 (Distance_decrease): 5.244191661 km
#   耗电 (Energy Consumed): 0.7341868325400001 kWh
#   是否充电 (Charging): Yes
#   充电量 (Energy Charged): 13.446645284615386 kWh
#   电量从 (Battery Start): 56.51387512358 kWh 变成 (Battery End): 69.22633357565539 kWh
#   剩余时间从 (Time Start): 1.6754803180096154 h 变成 (Time End): 1.5410138651634615 h
#   当前电池电量 (Battery): 69.22633361816406
#   剩余时间 (Remaining Time): 77.05068969726562
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: 80.71901621509227
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 44.0
#   剩余时间 (Remaining Time): 89.81895446777344
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 36 到节点 (To Node): 35
#   距离缩短 (Distance_decrease): 3.363793636 km
#   耗电 (Energy Consumed): 0.43729317268 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 44.0 kWh 变成 (Battery End): 43.56270682732 kWh
#   剩余时间从 (Time Start): 1.796379152 h 变成 (Time End): 1.7162888273333334 h
#   当前电池电量 (Battery): 43.562705993652344
#   剩余时间 (Remaining Time): 85.81443786621094
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -56.43729317268
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 38.0
#   剩余时间 (Remaining Time): 76.4347915649414
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# ------------------------------
#
# Step 1:
#   从节点 (From Node): 16 到节点 (To Node): 30
#   距离缩短 (Distance_decrease): 0.06255560000000315 km
#   耗电 (Energy Consumed): 0.02129844938 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 38.0 kWh 变成 (Battery End): 37.97870155062 kWh
#   剩余时间从 (Time Start): 1.528695807 h 变成 (Time End): 1.5258215223333333 h
#   当前电池电量 (Battery): 37.978702545166016
#   剩余时间 (Remaining Time): 76.29107666015625
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.1316622138
# Done: False
# ------------------------------
#
# Step 2:
#   从节点 (From Node): 30 到节点 (To Node): 16
#   距离缩短 (Distance_decrease): -0.06255560000000315 km
#   耗电 (Energy Consumed): 0.02129844938 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 37.97870155062 kWh 变成 (Battery End): 37.957403101240004 kWh
#   剩余时间从 (Time Start): 1.5258215223333333 h 变成 (Time End): 1.5229472376666666 h
#   当前电池电量 (Battery): 37.957401275634766
#   剩余时间 (Remaining Time): 76.1473617553711
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.2943067738
# Done: False
# ------------------------------
#
# Step 3:
#   从节点 (From Node): 16 到节点 (To Node): 30
#   距离缩短 (Distance_decrease): 0.06255560000000315 km
#   耗电 (Energy Consumed): 0.02129844938 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 37.957403101240004 kWh 变成 (Battery End): 37.936104651860006 kWh
#   剩余时间从 (Time Start): 1.5229472376666666 h 变成 (Time End): 1.520072953 h
#   当前电池电量 (Battery): 37.93610382080078
#   剩余时间 (Remaining Time): 76.00364685058594
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.1316622138
# Done: False
# ------------------------------
#
# Step 4:
#   从节点 (From Node): 30 到节点 (To Node): 16
#   距离缩短 (Distance_decrease): -0.06255560000000315 km
#   耗电 (Energy Consumed): 0.02129844938 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 37.936104651860006 kWh 变成 (Battery End): 37.91480620248001 kWh
#   剩余时间从 (Time Start): 1.520072953 h 变成 (Time End): 1.5171986683333332 h
#   当前电池电量 (Battery): 37.9148063659668
#   剩余时间 (Remaining Time): 75.85993194580078
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.2943067738
# Done: False
# ------------------------------
#
# Step 5:
#   从节点 (From Node): 16 到节点 (To Node): 30
#   距离缩短 (Distance_decrease): 0.06255560000000315 km
#   耗电 (Energy Consumed): 0.02129844938 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 37.91480620248001 kWh 变成 (Battery End): 37.89350775310001 kWh
#   剩余时间从 (Time Start): 1.5171986683333332 h 变成 (Time End): 1.5143243836666664 h
#   当前电池电量 (Battery): 37.89350891113281
#   剩余时间 (Remaining Time): 75.71621704101562
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.1316622138
# Done: False
# ------------------------------
#
# Step 6:
#   从节点 (From Node): 30 到节点 (To Node): 16
#   距离缩短 (Distance_decrease): -0.06255560000000315 km
#   耗电 (Energy Consumed): 0.02129844938 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 37.89350775310001 kWh 变成 (Battery End): 37.87220930372001 kWh
#   剩余时间从 (Time Start): 1.5143243836666664 h 变成 (Time End): 1.5114500989999997 h
#   当前电池电量 (Battery): 37.87220764160156
#   剩余时间 (Remaining Time): 75.57250213623047
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.2943067738
# Done: False
# ------------------------------
#
# Step 7:
#   从节点 (From Node): 16 到节点 (To Node): 30
#   距离缩短 (Distance_decrease): 0.06255560000000315 km
#   耗电 (Energy Consumed): 0.02129844938 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 37.87220930372001 kWh 变成 (Battery End): 37.850910854340015 kWh
#   剩余时间从 (Time Start): 1.5114500989999997 h 变成 (Time End): 1.508575814333333 h
#   当前电池电量 (Battery): 37.85091018676758
#   剩余时间 (Remaining Time): 75.42878723144531
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.1316622138
# Done: False
# ------------------------------
#
# Step 8:
#   从节点 (From Node): 30 到节点 (To Node): 16
#   距离缩短 (Distance_decrease): -0.06255560000000315 km
#   耗电 (Energy Consumed): 0.02129844938 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 37.850910854340015 kWh 变成 (Battery End): 37.82961240496002 kWh
#   剩余时间从 (Time Start): 1.508575814333333 h 变成 (Time End): 1.5057015296666663 h
#   当前电池电量 (Battery): 37.829612731933594
#   剩余时间 (Remaining Time): 75.28507995605469
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.2943067738
# Done: False
# ------------------------------
#
# Step 9:
#   从节点 (From Node): 16 到节点 (To Node): 30
#   距离缩短 (Distance_decrease): 0.06255560000000315 km
#   耗电 (Energy Consumed): 0.02129844938 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 37.82961240496002 kWh 变成 (Battery End): 37.80831395558002 kWh
#   剩余时间从 (Time Start): 1.5057015296666663 h 变成 (Time End): 1.5028272449999995 h
#   当前电池电量 (Battery): 37.80831527709961
#   剩余时间 (Remaining Time): 75.14136505126953
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.1316622138
# Done: False
# ------------------------------
#
# Step 10:
#   从节点 (From Node): 30 到节点 (To Node): 16
#   距离缩短 (Distance_decrease): -0.06255560000000315 km
#   耗电 (Energy Consumed): 0.02129844938 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 37.80831395558002 kWh 变成 (Battery End): 37.78701550620002 kWh
#   剩余时间从 (Time Start): 1.5028272449999995 h 变成 (Time End): 1.4999529603333328 h
#   当前电池电量 (Battery): 37.78701400756836
#   剩余时间 (Remaining Time): 74.99765014648438
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -100.2943067738
# Done: False
# ------------------------------
#
# Step 11:
#   从节点 (From Node): 16 到节点 (To Node): 30
#   距离缩短 (Distance_decrease): 0.06255560000000315 km
#   耗电 (Energy Consumed): 0.02129844938 kWh
#   是否充电 (Charging): No
#   电量从 (Battery Start): 37.78701550620002 kWh 变成 (Battery End): 37.76571705682002 kWh
#   剩余时间从 (Time Start): 1.4999529603333328 h 变成 (Time End): 1.497078675666666 h
#   当前电池电量 (Battery): 37.765716552734375
#   剩余时间 (Remaining Time): 74.85393524169922
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
# Reward: -8100.1316622138
# Done: True
# Episode finished! Resetting environment.
# Initial State:----------
#   当前电池电量 (Battery): 48.0
#   剩余时间 (Remaining Time): 82.92649841308594
#   其余节点的电量变化、距离变化和时间消耗信息已省略...
